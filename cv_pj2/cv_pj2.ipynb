# %%
import torch
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.init
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# 결과 재현성을 위해 랜덤 시드 고정
torch.manual_seed(777)
# GPU 사용 가능일 경우 랜덤 시드 고정
if device == 'cuda':
    torch.cuda.manual_seed_all(777)
learning_rate = 0.001
training_epochs = 15
batch_size = 50
mnist_train = dsets.MNIST(root = 'train/', # 다운로드 경로 지정
	train = True, # True를 지정하면 훈련 데이터로 다운로드
	transform = transforms.ToTensor(), # 텐서로 변환
	download = True)
mnist_test = dsets.MNIST(root = 'test/', # 다운로드 경로 지정
    train = False, # False를 지정하면 테스트 데이터로 다운로드
    transform = transforms.ToTensor(), # 텐서로 변환
    download = True)
data_loader = torch.utils.data.DataLoader(dataset = mnist_train,
    batch_size = batch_size,
    shuffle = True,
    drop_last = True)

class CNN(torch.nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
    	# 첫번째층
    	# ImgIn shape = (? , 28, 28, 1)
    	# Conv -> (? , 28, 28, 32)
    	# Pool -> (? , 14, 14, 32)
        self.layer1 = torch.nn.Sequential(
    		torch.nn.Conv2d(1, 32, kernel_size = 3, stride = 1, padding = 1),
    		torch.nn.ReLU(),
    		torch.nn.MaxPool2d(kernel_size = 2, stride = 2))
    	# 두번째층
    	# ImgIn shape = (? , 14, 14, 32)
    	# Conv ->(? , 14, 14, 64)
    	# Pool ->(? , 7, 7, 64)
        self.layer2 = torch.nn.Sequential(
    		torch.nn.Conv2d(32, 64, kernel_size = 3, stride = 1, padding = 1),
    		torch.nn.ReLU(),
    		torch.nn.MaxPool2d(kernel_size = 2, stride = 2))
    	# 전결합층 7x7x64 inputs -> 10 outputs
        self.fc = torch.nn.Linear(7 * 7 * 64, 10, bias = True)
    	# 전결합층 한정으로 가중치 초기화
        torch.nn.init.xavier_uniform_(self.fc.weight)
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1) # 전결합층을 위해서 Flatten
        out = self.fc(out)
        return out
# CNN 모델 정의
model = CNN().to(device)
criterion = torch.nn.CrossEntropyLoss().to(device) # 비용 함수에 소프트맥스 함수 포함되어져 있음.
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
total_batch = len(data_loader)
print('총 배치의 수 : {}'.format(total_batch))
for epoch in range(training_epochs) :
    avg_cost = 0
    for X, Y in data_loader : # 미니 배치 단위로 꺼내옴.X는 미니 배치, Y는 레이블.
        # image is already size of(28x28), no reshape
        # label is not one - hot encoded
        X = X.to(device)
        Y = Y.to(device)
        optimizer.zero_grad()
        hypothesis = model(X)
        cost = criterion(hypothesis, Y)
        cost.backward()
        optimizer.step()
        avg_cost += cost / total_batch
    print('[Epoch: {:>4}] cost = {:>.9}'.format(epoch + 1, avg_cost))

# 학습을 진행하지 않을 것이므로 torch.no_grad()
with torch.no_grad() :
    X_test = mnist_test.test_data.view(len(mnist_test), 1, 28, 28).float().to(device)
    Y_test = mnist_test.test_labels.to(device)
    prediction = model(X_test)
    correct_prediction = torch.argmax(prediction, 1) == Y_test
    accuracy = correct_prediction.float().mean()
    print('Accuracy:', accuracy.item())
# Out:
# 총 배치의 수 : 1200
# [Epoch:    1] cost = 0.169384092
# [Epoch:    2] cost = 0.0523789786
# [Epoch:    3] cost = 0.0385489017
# [Epoch:    4] cost = 0.0299722925
# [Epoch:    5] cost = 0.0236043707
# [Epoch:    6] cost = 0.0196063705
# [Epoch:    7] cost = 0.0158073213
# [Epoch:    8] cost = 0.0137237655
# [Epoch:    9] cost = 0.0101975333
# [Epoch:   10] cost = 0.00884883106
# [Epoch:   11] cost = 0.00725776609
# [Epoch:   12] cost = 0.00657538697
# [Epoch:   13] cost = 0.0050253165
# [Epoch:   14] cost = 0.00526297977
# [Epoch:   15] cost = 0.00389165478
# C:\Users\kong7\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\kong7\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# Accuracy: 0.9811000227928162

# %%
import os
from PIL import Image
import numpy as np
import cv2
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from skimage.morphology import thin, skeletonize
from skimage.filters import threshold_otsu
from skimage.measure import find_contours
from skimage.transform import rotate
from scipy.ndimage import shift
from skimage.transform import warp

np.random.seed(42) # random값 고정

class CustomImageDataset:
    def read_data_set(self):
        all_img_files = []
        all_labels = []

        class_names = os.walk(self.data_set_path).__next__()[1]

        for index, class_name in enumerate(class_names):
            label = index
            img_dir = os.path.join(self.data_set_path, class_name)
            img_files = os.walk(img_dir).__next__()[2]

            for img_file in img_files:
                img_file = os.path.join(img_dir, img_file)
                img = Image.open(img_file)
                if img is not None:
                    all_img_files.append(img_file)
                    all_labels.append(label)

        return all_img_files, all_labels, len(all_img_files), len(class_names)

    def __init__(self, data_set_path):
        self.data_set_path = data_set_path
        self.image_files_path, self.labels, self.length, self.num_classes = self.read_data_set()

    def __getitem__(self, index):
        image = Image.open(self.image_files_path[index])
        image = image.convert("L")  # Convert to grayscale
        image = np.array(image)

        # 이진화 적용
        thresh = threshold_otsu(image)
        binary = image > thresh

        # 숫자 영역 탐지 및 잘라내기
        contours = find_contours(binary, 0.8)
        if len(contours) > 0:
            # 가장 큰 윤곽선 선택
            contour = max(contours, key=lambda c: c.shape[0])
            # 윤곽선의 좌표 추출
            y, x = contour.T
            # 윤곽선의 경계 좌표 계산
            x_min, x_max = x.min(), x.max()
            y_min, y_max = y.min(), y.max()
            # 숫자 영역 잘라내기
            cropped = binary[int(y_min):int(y_max), int(x_min):int(x_max)]
        else:
            # 윤곽선이 없는 경우 이진화된 이미지 그대로 사용
            cropped = binary
            
        # 크기 정규화
        cropped = np.array(Image.fromarray(cropped).resize((32, 32)))

        # 모폴로지 연산 적용
        thinned = thin(cropped)
        skeleton = skeletonize(thinned)

        # 특성 추출
        features = self.extract_features(skeleton)

        return features, self.labels[index]

    def __len__(self):
        return self.length

    def extract_features(self, image):
        # 이미지를 1차원 배열로 변환
        features = image.flatten()

        return features


def augment_data(X, y):
    augmented_X = []
    augmented_y = []

    for image, label in zip(X, y):
        # 원본 이미지 추가
        augmented_X.append(image)
        augmented_y.append(label)

        # 회전 변환 추가
        for angle in [-5, 5]:
            rotated_image = rotate(image.reshape(32, 32), angle).flatten()
            augmented_X.append(rotated_image)
            augmented_y.append(label)

        # 이동 변환 추가
        for shift_x, shift_y in [(2, 0), (-2, 0), (0, 2), (0, -2)]:
            shifted_image = shift(image.reshape(32, 32), (shift_x, shift_y), mode='constant').flatten()
            augmented_X.append(shifted_image)
            augmented_y.append(label)

        image_reshaped = image.reshape(32, 32)
        mapping = np.indices((32, 32)).transpose(1, 2, 0).astype(np.float64)
        mapping += np.random.rand(*mapping.shape) * 7
        mapping = mapping.transpose(2, 0, 1)  # Transpose to (2, 32, 32)
        curved_image = warp(image_reshaped, mapping, mode='wrap').flatten()
        augmented_X.append(curved_image)
        augmented_y.append(label)
        
    return np.array(augmented_X), np.array(augmented_y)

train_data_set = CustomImageDataset(data_set_path="./train")
test_data_set = CustomImageDataset(data_set_path="./test")

if not (train_data_set.num_classes == test_data_set.num_classes):
    print("error: Numbers of class in training set and test set are not equal")
    exit()

X_train, y_train = zip(*[train_data_set[i] for i in range(len(train_data_set))])
X_test, y_test = zip(*[test_data_set[i] for i in range(len(test_data_set))])

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

# 데이터 증강 적용
X_train, y_train = augment_data(X_train, y_train)

# Create a Gaussian Naive Bayes classifier
clf = GaussianNB()

# Train the classifier
clf.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = clf.predict(X_test)

# Calculate the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100, "%")
# Out:
# Accuracy: 85.0 %

# %%
import os
from PIL import Image

import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torchvision import transforms


class CustomImageDataset(Dataset):
    def read_data_set(self):

        all_img_files = []
        all_labels = []

        class_names = os.walk(self.data_set_path).__next__()[1]

        for index, class_name in enumerate(class_names):
            label = index
            img_dir = os.path.join(self.data_set_path, class_name)
            img_files = os.walk(img_dir).__next__()[2]

            for img_file in img_files:
                img_file = os.path.join(img_dir, img_file)
                img = Image.open(img_file)
                if img is not None:
                    all_img_files.append(img_file)
                    all_labels.append(label)

        return all_img_files, all_labels, len(all_img_files), len(class_names)

    def __init__(self, data_set_path, transforms=None):
        self.data_set_path = data_set_path
        self.image_files_path, self.labels, self.length, self.num_classes = self.read_data_set()
        self.transforms = transforms

    def __getitem__(self, index):
        image = Image.open(self.image_files_path[index])
        image = image.convert("RGB")

        if self.transforms is not None:
            image = self.transforms(image)

        return {'image': image, 'label': self.labels[index]}

    def __len__(self):
        return self.length


class CustomConvNet(nn.Module):
    def __init__(self, num_classes):
        super(CustomConvNet, self).__init__()

        self.layer1 = self.conv_module(3, 16)
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, num_classes)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, num_classes)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1, 1)))


hyper_param_epoch = 20
hyper_param_batch = 8
hyper_param_learning_rate = 0.001

transforms_train = transforms.Compose([transforms.Resize((128, 128)),
                                       transforms.RandomRotation(10.),
                                       transforms.ToTensor()])

transforms_test = transforms.Compose([transforms.Resize((128, 128)),
                                      transforms.ToTensor()])

train_data_set = CustomImageDataset(data_set_path="./train", transforms=transforms_train)
train_loader = DataLoader(train_data_set, batch_size=hyper_param_batch, shuffle=True)

test_data_set = CustomImageDataset(data_set_path="./test", transforms=transforms_test)
test_loader = DataLoader(test_data_set, batch_size=hyper_param_batch, shuffle=True)

if not (train_data_set.num_classes == test_data_set.num_classes):
    print("error: Numbers of class in training set and test set are not equal")
    exit()

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

num_classes = train_data_set.num_classes
custom_model = CustomConvNet(num_classes=num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)

for e in range(hyper_param_epoch):
    for i_batch, item in enumerate(train_loader):
        images = item['image'].to(device)
        labels = item['label'].to(device)

        # Forward pass
        outputs = custom_model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i_batch + 1) % hyper_param_batch == 0:
            print('Epoch [{}/{}], Loss: {:.4f}'
                  .format(e + 1, hyper_param_epoch, loss.item()))

# Test the model
custom_model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        images = item['image'].to(device)
        labels = item['label'].to(device)
        outputs = custom_model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += len(labels)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Epoch [1/30], Loss: 1.6781
# Epoch [2/30], Loss: 1.2937
# Epoch [3/30], Loss: 1.3520
# Epoch [4/30], Loss: 1.6942
# Epoch [5/30], Loss: 1.1172
# Epoch [6/30], Loss: 1.0233
# Epoch [7/30], Loss: 1.0070
# Epoch [8/30], Loss: 1.0377
# Epoch [9/30], Loss: 1.1071
# Epoch [10/30], Loss: 1.1089
# Epoch [11/30], Loss: 0.7011
# Epoch [12/30], Loss: 0.7619
# Epoch [13/30], Loss: 0.7036
# Epoch [14/30], Loss: 0.5623
# Epoch [15/30], Loss: 0.8458
# Epoch [16/30], Loss: 0.6536
# Epoch [17/30], Loss: 0.8533
# Epoch [18/30], Loss: 0.6321
# Epoch [19/30], Loss: 0.6169
# Epoch [20/30], Loss: 0.8469
# Epoch [21/30], Loss: 0.4531
# Epoch [22/30], Loss: 0.7140
# Epoch [23/30], Loss: 0.5836
# Epoch [24/30], Loss: 0.4722
# Epoch [25/30], Loss: 0.6766
# Epoch [26/30], Loss: 0.6483
# Epoch [27/30], Loss: 0.4565
# Epoch [28/30], Loss: 0.6136
# Epoch [29/30], Loss: 0.5193
# Epoch [30/30], Loss: 0.4712
# Test Accuracy of the model on the 20 test images: 100.0 %

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

class CustomImageDataset(Dataset):
    def read_data_set(self):
        all_img_files = []
        all_labels = []

        class_names = os.walk(self.data_set_path).__next__()[1]

        for index, class_name in enumerate(class_names):
            label = index
            img_dir = os.path.join(self.data_set_path, class_name)
            img_files = os.walk(img_dir).__next__()[2]

            for img_file in img_files:
                img_file = os.path.join(img_dir, img_file)
                img = Image.open(img_file)
                if img is not None:
                    all_img_files.append(img_file)
                    all_labels.append(label)

        return all_img_files, all_labels, len(all_img_files), len(class_names)

    def __init__(self, data_set_path):
        self.data_set_path = data_set_path
        self.image_files_path, self.labels, self.length, self.num_classes = self.read_data_set()

    def __getitem__(self, index):
        image = Image.open(self.image_files_path[index])
        image = image.convert("L")
        image = image.resize((28, 28))
        image = np.array(image).astype(np.float32) / 255.0
        image = torch.from_numpy(image.reshape(-1)).float()
        label = torch.tensor(self.labels[index]).long()
        return image, label

    def __len__(self):
        return self.length

class Net(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

def train(model, device, train_loader, criterion, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

def test(model, device, test_loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    accuracy = 100. * correct / len(test_loader.dataset)
    return accuracy

train_data_set = CustomImageDataset(data_set_path="./train")
test_data_set = CustomImageDataset(data_set_path="./test")

batch_size = 64
train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = 28 * 28
hidden_size = 128
num_classes = train_data_set.num_classes
model = Net(input_size, hidden_size, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 1000  # 에포크 수를 200으로 증가
best_accuracy = 0.0

for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, criterion, optimizer, epoch)
    accuracy = test(model, device, test_loader)
    print(f"Epoch [{epoch}/{num_epochs}], Test Accuracy: {accuracy:.2f}%")
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), "best_model.pth")  # 최고 성능 모델 저장

print(f"Best Test Accuracy: {best_accuracy:.2f}%")
# Out:
# Epoch [1/1000], Test Accuracy: 25.00%
# Epoch [2/1000], Test Accuracy: 25.00%
# Epoch [3/1000], Test Accuracy: 25.00%
# Epoch [4/1000], Test Accuracy: 25.00%
# Epoch [5/1000], Test Accuracy: 30.00%
# Epoch [6/1000], Test Accuracy: 25.00%
# Epoch [7/1000], Test Accuracy: 25.00%
# Epoch [8/1000], Test Accuracy: 25.00%
# Epoch [9/1000], Test Accuracy: 25.00%
# Epoch [10/1000], Test Accuracy: 25.00%
# Epoch [11/1000], Test Accuracy: 25.00%
# Epoch [12/1000], Test Accuracy: 25.00%
# Epoch [13/1000], Test Accuracy: 35.00%
# Epoch [14/1000], Test Accuracy: 50.00%
# Epoch [15/1000], Test Accuracy: 25.00%
# Epoch [16/1000], Test Accuracy: 25.00%
# Epoch [17/1000], Test Accuracy: 25.00%
# Epoch [18/1000], Test Accuracy: 35.00%
# Epoch [19/1000], Test Accuracy: 35.00%
# Epoch [20/1000], Test Accuracy: 45.00%
# Epoch [21/1000], Test Accuracy: 25.00%
# Epoch [22/1000], Test Accuracy: 25.00%
# Epoch [23/1000], Test Accuracy: 20.00%
# Epoch [24/1000], Test Accuracy: 35.00%
# Epoch [25/1000], Test Accuracy: 40.00%
# Epoch [26/1000], Test Accuracy: 25.00%
# Epoch [27/1000], Test Accuracy: 25.00%
# Epoch [28/1000], Test Accuracy: 40.00%
# Epoch [29/1000], Test Accuracy: 25.00%
# Epoch [30/1000], Test Accuracy: 25.00%
# Epoch [31/1000], Test Accuracy: 55.00%
# Epoch [32/1000], Test Accuracy: 40.00%
# Epoch [33/1000], Test Accuracy: 25.00%
# Epoch [34/1000], Test Accuracy: 25.00%
# Epoch [35/1000], Test Accuracy: 25.00%
# Epoch [36/1000], Test Accuracy: 40.00%
# Epoch [37/1000], Test Accuracy: 55.00%
# Epoch [38/1000], Test Accuracy: 40.00%
# Epoch [39/1000], Test Accuracy: 30.00%
# Epoch [40/1000], Test Accuracy: 30.00%
# Epoch [41/1000], Test Accuracy: 45.00%
# Epoch [42/1000], Test Accuracy: 60.00%
# Epoch [43/1000], Test Accuracy: 40.00%
# Epoch [44/1000], Test Accuracy: 35.00%
# Epoch [45/1000], Test Accuracy: 45.00%
# Epoch [46/1000], Test Accuracy: 30.00%
# Epoch [47/1000], Test Accuracy: 50.00%
# Epoch [48/1000], Test Accuracy: 45.00%
# Epoch [49/1000], Test Accuracy: 60.00%
# Epoch [50/1000], Test Accuracy: 40.00%
# Epoch [51/1000], Test Accuracy: 35.00%
# Epoch [52/1000], Test Accuracy: 50.00%
# Epoch [53/1000], Test Accuracy: 45.00%
# Epoch [54/1000], Test Accuracy: 45.00%
# Epoch [55/1000], Test Accuracy: 35.00%
# Epoch [56/1000], Test Accuracy: 25.00%
# Epoch [57/1000], Test Accuracy: 30.00%
# Epoch [58/1000], Test Accuracy: 20.00%
# Epoch [59/1000], Test Accuracy: 35.00%
# Epoch [60/1000], Test Accuracy: 40.00%
# Epoch [61/1000], Test Accuracy: 50.00%
# Epoch [62/1000], Test Accuracy: 45.00%
# Epoch [63/1000], Test Accuracy: 65.00%
# Epoch [64/1000], Test Accuracy: 40.00%
# Epoch [65/1000], Test Accuracy: 35.00%
# Epoch [66/1000], Test Accuracy: 40.00%
# Epoch [67/1000], Test Accuracy: 50.00%
# Epoch [68/1000], Test Accuracy: 80.00%
# Epoch [69/1000], Test Accuracy: 55.00%
# Epoch [70/1000], Test Accuracy: 55.00%
# Epoch [71/1000], Test Accuracy: 50.00%
# Epoch [72/1000], Test Accuracy: 40.00%
# Epoch [73/1000], Test Accuracy: 55.00%
# Epoch [74/1000], Test Accuracy: 55.00%
# Epoch [75/1000], Test Accuracy: 55.00%
# Epoch [76/1000], Test Accuracy: 70.00%
# Epoch [77/1000], Test Accuracy: 75.00%
# Epoch [78/1000], Test Accuracy: 80.00%
# Epoch [79/1000], Test Accuracy: 80.00%
# Epoch [80/1000], Test Accuracy: 60.00%
# Epoch [81/1000], Test Accuracy: 45.00%
# Epoch [82/1000], Test Accuracy: 55.00%
# Epoch [83/1000], Test Accuracy: 60.00%
# Epoch [84/1000], Test Accuracy: 75.00%
# Epoch [85/1000], Test Accuracy: 35.00%
# Epoch [86/1000], Test Accuracy: 55.00%
# Epoch [87/1000], Test Accuracy: 55.00%
# Epoch [88/1000], Test Accuracy: 60.00%
# Epoch [89/1000], Test Accuracy: 60.00%
# Epoch [90/1000], Test Accuracy: 75.00%
# Epoch [91/1000], Test Accuracy: 30.00%
# Epoch [92/1000], Test Accuracy: 55.00%
# Epoch [93/1000], Test Accuracy: 45.00%
# Epoch [94/1000], Test Accuracy: 50.00%
# Epoch [95/1000], Test Accuracy: 55.00%
# Epoch [96/1000], Test Accuracy: 80.00%
# Epoch [97/1000], Test Accuracy: 30.00%
# Epoch [98/1000], Test Accuracy: 30.00%
# Epoch [99/1000], Test Accuracy: 60.00%
# Epoch [100/1000], Test Accuracy: 55.00%
# Epoch [101/1000], Test Accuracy: 50.00%
# Epoch [102/1000], Test Accuracy: 60.00%
# Epoch [103/1000], Test Accuracy: 65.00%
# Epoch [104/1000], Test Accuracy: 55.00%
# Epoch [105/1000], Test Accuracy: 40.00%
# Epoch [106/1000], Test Accuracy: 70.00%
# Epoch [107/1000], Test Accuracy: 80.00%
# Epoch [108/1000], Test Accuracy: 75.00%
# Epoch [109/1000], Test Accuracy: 75.00%
# Epoch [110/1000], Test Accuracy: 65.00%
# Epoch [111/1000], Test Accuracy: 65.00%
# Epoch [112/1000], Test Accuracy: 60.00%
# Epoch [113/1000], Test Accuracy: 60.00%
# Epoch [114/1000], Test Accuracy: 65.00%
# Epoch [115/1000], Test Accuracy: 75.00%
# Epoch [116/1000], Test Accuracy: 65.00%
# Epoch [117/1000], Test Accuracy: 75.00%
# Epoch [118/1000], Test Accuracy: 80.00%
# Epoch [119/1000], Test Accuracy: 80.00%
# Epoch [120/1000], Test Accuracy: 60.00%
# Epoch [121/1000], Test Accuracy: 55.00%
# Epoch [122/1000], Test Accuracy: 65.00%
# Epoch [123/1000], Test Accuracy: 70.00%
# Epoch [124/1000], Test Accuracy: 80.00%
# Epoch [125/1000], Test Accuracy: 60.00%
# Epoch [126/1000], Test Accuracy: 40.00%
# Epoch [127/1000], Test Accuracy: 75.00%
# Epoch [128/1000], Test Accuracy: 85.00%
# Epoch [129/1000], Test Accuracy: 70.00%
# Epoch [130/1000], Test Accuracy: 65.00%
# Epoch [131/1000], Test Accuracy: 60.00%
# Epoch [132/1000], Test Accuracy: 40.00%
# Epoch [133/1000], Test Accuracy: 60.00%
# Epoch [134/1000], Test Accuracy: 55.00%
# Epoch [135/1000], Test Accuracy: 75.00%
# Epoch [136/1000], Test Accuracy: 75.00%
# Epoch [137/1000], Test Accuracy: 65.00%
# Epoch [138/1000], Test Accuracy: 75.00%
# Epoch [139/1000], Test Accuracy: 60.00%
# Epoch [140/1000], Test Accuracy: 65.00%
# Epoch [141/1000], Test Accuracy: 55.00%
# Epoch [142/1000], Test Accuracy: 55.00%
# Epoch [143/1000], Test Accuracy: 60.00%
# Epoch [144/1000], Test Accuracy: 60.00%
# Epoch [145/1000], Test Accuracy: 65.00%
# Epoch [146/1000], Test Accuracy: 70.00%
# Epoch [147/1000], Test Accuracy: 60.00%
# Epoch [148/1000], Test Accuracy: 60.00%
# Epoch [149/1000], Test Accuracy: 50.00%
# Epoch [150/1000], Test Accuracy: 60.00%
# Epoch [151/1000], Test Accuracy: 65.00%
# Epoch [152/1000], Test Accuracy: 60.00%
# Epoch [153/1000], Test Accuracy: 55.00%
# Epoch [154/1000], Test Accuracy: 75.00%
# Epoch [155/1000], Test Accuracy: 70.00%
# Epoch [156/1000], Test Accuracy: 60.00%
# Epoch [157/1000], Test Accuracy: 60.00%
# Epoch [158/1000], Test Accuracy: 60.00%
# Epoch [159/1000], Test Accuracy: 65.00%
# Epoch [160/1000], Test Accuracy: 65.00%
# Epoch [161/1000], Test Accuracy: 75.00%
# Epoch [162/1000], Test Accuracy: 65.00%
# Epoch [163/1000], Test Accuracy: 60.00%
# Epoch [164/1000], Test Accuracy: 65.00%
# Epoch [165/1000], Test Accuracy: 65.00%
# Epoch [166/1000], Test Accuracy: 75.00%
# Epoch [167/1000], Test Accuracy: 70.00%
# Epoch [168/1000], Test Accuracy: 55.00%
# Epoch [169/1000], Test Accuracy: 65.00%
# Epoch [170/1000], Test Accuracy: 75.00%
# Epoch [171/1000], Test Accuracy: 55.00%
# Epoch [172/1000], Test Accuracy: 50.00%
# Epoch [173/1000], Test Accuracy: 60.00%
# Epoch [174/1000], Test Accuracy: 80.00%
# Epoch [175/1000], Test Accuracy: 60.00%
# Epoch [176/1000], Test Accuracy: 60.00%
# Epoch [177/1000], Test Accuracy: 60.00%
# Epoch [178/1000], Test Accuracy: 55.00%
# Epoch [179/1000], Test Accuracy: 65.00%
# Epoch [180/1000], Test Accuracy: 65.00%
# Epoch [181/1000], Test Accuracy: 65.00%
# Epoch [182/1000], Test Accuracy: 70.00%
# Epoch [183/1000], Test Accuracy: 65.00%
# Epoch [184/1000], Test Accuracy: 60.00%
# Epoch [185/1000], Test Accuracy: 70.00%
# Epoch [186/1000], Test Accuracy: 65.00%
# Epoch [187/1000], Test Accuracy: 75.00%
# Epoch [188/1000], Test Accuracy: 55.00%
# Epoch [189/1000], Test Accuracy: 55.00%
# Epoch [190/1000], Test Accuracy: 60.00%
# Epoch [191/1000], Test Accuracy: 75.00%
# Epoch [192/1000], Test Accuracy: 65.00%
# Epoch [193/1000], Test Accuracy: 65.00%
# Epoch [194/1000], Test Accuracy: 60.00%
# Epoch [195/1000], Test Accuracy: 75.00%
# Epoch [196/1000], Test Accuracy: 70.00%
# Epoch [197/1000], Test Accuracy: 70.00%
# Epoch [198/1000], Test Accuracy: 60.00%
# Epoch [199/1000], Test Accuracy: 65.00%
# Epoch [200/1000], Test Accuracy: 65.00%
# Epoch [201/1000], Test Accuracy: 75.00%
# Epoch [202/1000], Test Accuracy: 50.00%
# Epoch [203/1000], Test Accuracy: 55.00%
# Epoch [204/1000], Test Accuracy: 75.00%
# Epoch [205/1000], Test Accuracy: 65.00%
# Epoch [206/1000], Test Accuracy: 55.00%
# Epoch [207/1000], Test Accuracy: 60.00%
# Epoch [208/1000], Test Accuracy: 60.00%
# Epoch [209/1000], Test Accuracy: 75.00%
# Epoch [210/1000], Test Accuracy: 65.00%
# Epoch [211/1000], Test Accuracy: 80.00%
# Epoch [212/1000], Test Accuracy: 50.00%
# Epoch [213/1000], Test Accuracy: 55.00%
# Epoch [214/1000], Test Accuracy: 65.00%
# Epoch [215/1000], Test Accuracy: 70.00%
# Epoch [216/1000], Test Accuracy: 75.00%
# Epoch [217/1000], Test Accuracy: 65.00%
# Epoch [218/1000], Test Accuracy: 60.00%
# Epoch [219/1000], Test Accuracy: 70.00%
# Epoch [220/1000], Test Accuracy: 75.00%
# Epoch [221/1000], Test Accuracy: 75.00%
# Epoch [222/1000], Test Accuracy: 80.00%
# Epoch [223/1000], Test Accuracy: 75.00%
# Epoch [224/1000], Test Accuracy: 65.00%
# Epoch [225/1000], Test Accuracy: 65.00%
# Epoch [226/1000], Test Accuracy: 75.00%
# Epoch [227/1000], Test Accuracy: 65.00%
# Epoch [228/1000], Test Accuracy: 60.00%
# Epoch [229/1000], Test Accuracy: 70.00%
# Epoch [230/1000], Test Accuracy: 65.00%
# Epoch [231/1000], Test Accuracy: 80.00%
# Epoch [232/1000], Test Accuracy: 60.00%
# Epoch [233/1000], Test Accuracy: 60.00%
# Epoch [234/1000], Test Accuracy: 75.00%
# Epoch [235/1000], Test Accuracy: 70.00%
# Epoch [236/1000], Test Accuracy: 75.00%
# Epoch [237/1000], Test Accuracy: 75.00%
# Epoch [238/1000], Test Accuracy: 60.00%
# Epoch [239/1000], Test Accuracy: 70.00%
# Epoch [240/1000], Test Accuracy: 55.00%
# Epoch [241/1000], Test Accuracy: 85.00%
# Epoch [242/1000], Test Accuracy: 75.00%
# Epoch [243/1000], Test Accuracy: 65.00%
# Epoch [244/1000], Test Accuracy: 65.00%
# Epoch [245/1000], Test Accuracy: 75.00%
# Epoch [246/1000], Test Accuracy: 60.00%
# Epoch [247/1000], Test Accuracy: 65.00%
# Epoch [248/1000], Test Accuracy: 75.00%
# Epoch [249/1000], Test Accuracy: 65.00%
# Epoch [250/1000], Test Accuracy: 65.00%
# Epoch [251/1000], Test Accuracy: 75.00%
# Epoch [252/1000], Test Accuracy: 85.00%
# Epoch [253/1000], Test Accuracy: 75.00%
# Epoch [254/1000], Test Accuracy: 60.00%
# Epoch [255/1000], Test Accuracy: 60.00%
# Epoch [256/1000], Test Accuracy: 70.00%
# Epoch [257/1000], Test Accuracy: 75.00%
# Epoch [258/1000], Test Accuracy: 70.00%
# Epoch [259/1000], Test Accuracy: 65.00%
# Epoch [260/1000], Test Accuracy: 65.00%
# Epoch [261/1000], Test Accuracy: 60.00%
# Epoch [262/1000], Test Accuracy: 75.00%
# Epoch [263/1000], Test Accuracy: 65.00%
# Epoch [264/1000], Test Accuracy: 70.00%
# Epoch [265/1000], Test Accuracy: 65.00%
# Epoch [266/1000], Test Accuracy: 55.00%
# Epoch [267/1000], Test Accuracy: 80.00%
# Epoch [268/1000], Test Accuracy: 70.00%
# Epoch [269/1000], Test Accuracy: 70.00%
# Epoch [270/1000], Test Accuracy: 65.00%
# Epoch [271/1000], Test Accuracy: 65.00%
# Epoch [272/1000], Test Accuracy: 75.00%
# Epoch [273/1000], Test Accuracy: 75.00%
# Epoch [274/1000], Test Accuracy: 80.00%
# Epoch [275/1000], Test Accuracy: 65.00%
# Epoch [276/1000], Test Accuracy: 65.00%
# Epoch [277/1000], Test Accuracy: 70.00%
# Epoch [278/1000], Test Accuracy: 70.00%
# Epoch [279/1000], Test Accuracy: 80.00%
# Epoch [280/1000], Test Accuracy: 65.00%
# Epoch [281/1000], Test Accuracy: 60.00%
# Epoch [282/1000], Test Accuracy: 75.00%
# Epoch [283/1000], Test Accuracy: 80.00%
# Epoch [284/1000], Test Accuracy: 75.00%
# Epoch [285/1000], Test Accuracy: 65.00%
# Epoch [286/1000], Test Accuracy: 75.00%
# Epoch [287/1000], Test Accuracy: 80.00%
# Epoch [288/1000], Test Accuracy: 75.00%
# Epoch [289/1000], Test Accuracy: 60.00%
# Epoch [290/1000], Test Accuracy: 65.00%
# Epoch [291/1000], Test Accuracy: 75.00%
# Epoch [292/1000], Test Accuracy: 70.00%
# Epoch [293/1000], Test Accuracy: 75.00%
# Epoch [294/1000], Test Accuracy: 70.00%
# Epoch [295/1000], Test Accuracy: 70.00%
# Epoch [296/1000], Test Accuracy: 70.00%
# Epoch [297/1000], Test Accuracy: 65.00%
# Epoch [298/1000], Test Accuracy: 65.00%
# Epoch [299/1000], Test Accuracy: 70.00%
# Epoch [300/1000], Test Accuracy: 75.00%
# Epoch [301/1000], Test Accuracy: 80.00%
# Epoch [302/1000], Test Accuracy: 60.00%
# Epoch [303/1000], Test Accuracy: 60.00%
# Epoch [304/1000], Test Accuracy: 75.00%
# Epoch [305/1000], Test Accuracy: 65.00%
# Epoch [306/1000], Test Accuracy: 65.00%
# Epoch [307/1000], Test Accuracy: 65.00%
# Epoch [308/1000], Test Accuracy: 70.00%
# Epoch [309/1000], Test Accuracy: 75.00%
# Epoch [310/1000], Test Accuracy: 60.00%
# Epoch [311/1000], Test Accuracy: 60.00%
# Epoch [312/1000], Test Accuracy: 60.00%
# Epoch [313/1000], Test Accuracy: 65.00%
# Epoch [314/1000], Test Accuracy: 70.00%
# Epoch [315/1000], Test Accuracy: 60.00%
# Epoch [316/1000], Test Accuracy: 65.00%
# Epoch [317/1000], Test Accuracy: 60.00%
# Epoch [318/1000], Test Accuracy: 70.00%
# Epoch [319/1000], Test Accuracy: 65.00%
# Epoch [320/1000], Test Accuracy: 70.00%
# Epoch [321/1000], Test Accuracy: 50.00%
# Epoch [322/1000], Test Accuracy: 60.00%
# Epoch [323/1000], Test Accuracy: 60.00%
# Epoch [324/1000], Test Accuracy: 60.00%
# Epoch [325/1000], Test Accuracy: 80.00%
# Epoch [326/1000], Test Accuracy: 60.00%
# Epoch [327/1000], Test Accuracy: 50.00%
# Epoch [328/1000], Test Accuracy: 55.00%
# Epoch [329/1000], Test Accuracy: 65.00%
# Epoch [330/1000], Test Accuracy: 55.00%
# Epoch [331/1000], Test Accuracy: 60.00%
# Epoch [332/1000], Test Accuracy: 60.00%
# Epoch [333/1000], Test Accuracy: 75.00%
# Epoch [334/1000], Test Accuracy: 65.00%
# Epoch [335/1000], Test Accuracy: 70.00%
# Epoch [336/1000], Test Accuracy: 65.00%
# Epoch [337/1000], Test Accuracy: 65.00%
# Epoch [338/1000], Test Accuracy: 80.00%
# Epoch [339/1000], Test Accuracy: 80.00%
# Epoch [340/1000], Test Accuracy: 70.00%
# Epoch [341/1000], Test Accuracy: 65.00%
# Epoch [342/1000], Test Accuracy: 70.00%
# Epoch [343/1000], Test Accuracy: 70.00%
# Epoch [344/1000], Test Accuracy: 65.00%
# Epoch [345/1000], Test Accuracy: 75.00%
# Epoch [346/1000], Test Accuracy: 75.00%
# Epoch [347/1000], Test Accuracy: 75.00%
# Epoch [348/1000], Test Accuracy: 65.00%
# Epoch [349/1000], Test Accuracy: 70.00%
# Epoch [350/1000], Test Accuracy: 75.00%
# Epoch [351/1000], Test Accuracy: 70.00%
# Epoch [352/1000], Test Accuracy: 70.00%
# Epoch [353/1000], Test Accuracy: 65.00%
# Epoch [354/1000], Test Accuracy: 65.00%
# Epoch [355/1000], Test Accuracy: 75.00%
# Epoch [356/1000], Test Accuracy: 80.00%
# Epoch [357/1000], Test Accuracy: 80.00%
# Epoch [358/1000], Test Accuracy: 75.00%
# Epoch [359/1000], Test Accuracy: 75.00%
# Epoch [360/1000], Test Accuracy: 65.00%
# Epoch [361/1000], Test Accuracy: 70.00%
# Epoch [362/1000], Test Accuracy: 75.00%
# Epoch [363/1000], Test Accuracy: 75.00%
# Epoch [364/1000], Test Accuracy: 70.00%
# Epoch [365/1000], Test Accuracy: 65.00%
# Epoch [366/1000], Test Accuracy: 70.00%
# Epoch [367/1000], Test Accuracy: 75.00%
# Epoch [368/1000], Test Accuracy: 80.00%
# Epoch [369/1000], Test Accuracy: 65.00%
# Epoch [370/1000], Test Accuracy: 65.00%
# Epoch [371/1000], Test Accuracy: 70.00%
# Epoch [372/1000], Test Accuracy: 75.00%
# Epoch [373/1000], Test Accuracy: 70.00%
# Epoch [374/1000], Test Accuracy: 65.00%
# Epoch [375/1000], Test Accuracy: 70.00%
# Epoch [376/1000], Test Accuracy: 70.00%
# Epoch [377/1000], Test Accuracy: 80.00%
# Epoch [378/1000], Test Accuracy: 70.00%
# Epoch [379/1000], Test Accuracy: 65.00%
# Epoch [380/1000], Test Accuracy: 60.00%
# Epoch [381/1000], Test Accuracy: 70.00%
# Epoch [382/1000], Test Accuracy: 80.00%
# Epoch [383/1000], Test Accuracy: 65.00%
# Epoch [384/1000], Test Accuracy: 65.00%
# Epoch [385/1000], Test Accuracy: 65.00%
# Epoch [386/1000], Test Accuracy: 70.00%
# Epoch [387/1000], Test Accuracy: 75.00%
# Epoch [388/1000], Test Accuracy: 65.00%
# Epoch [389/1000], Test Accuracy: 65.00%
# Epoch [390/1000], Test Accuracy: 80.00%
# Epoch [391/1000], Test Accuracy: 75.00%
# Epoch [392/1000], Test Accuracy: 75.00%
# Epoch [393/1000], Test Accuracy: 60.00%
# Epoch [394/1000], Test Accuracy: 65.00%
# Epoch [395/1000], Test Accuracy: 75.00%
# Epoch [396/1000], Test Accuracy: 65.00%
# Epoch [397/1000], Test Accuracy: 75.00%
# Epoch [398/1000], Test Accuracy: 65.00%
# Epoch [399/1000], Test Accuracy: 60.00%
# Epoch [400/1000], Test Accuracy: 75.00%
# Epoch [401/1000], Test Accuracy: 80.00%
# Epoch [402/1000], Test Accuracy: 75.00%
# Epoch [403/1000], Test Accuracy: 75.00%
# Epoch [404/1000], Test Accuracy: 65.00%
# Epoch [405/1000], Test Accuracy: 65.00%
# Epoch [406/1000], Test Accuracy: 75.00%
# Epoch [407/1000], Test Accuracy: 70.00%
# Epoch [408/1000], Test Accuracy: 70.00%
# Epoch [409/1000], Test Accuracy: 70.00%
# Epoch [410/1000], Test Accuracy: 80.00%
# Epoch [411/1000], Test Accuracy: 80.00%
# Epoch [412/1000], Test Accuracy: 75.00%
# Epoch [413/1000], Test Accuracy: 65.00%
# Epoch [414/1000], Test Accuracy: 70.00%
# Epoch [415/1000], Test Accuracy: 80.00%
# Epoch [416/1000], Test Accuracy: 85.00%
# Epoch [417/1000], Test Accuracy: 70.00%
# Epoch [418/1000], Test Accuracy: 70.00%
# Epoch [419/1000], Test Accuracy: 70.00%
# Epoch [420/1000], Test Accuracy: 70.00%
# Epoch [421/1000], Test Accuracy: 70.00%
# Epoch [422/1000], Test Accuracy: 75.00%
# Epoch [423/1000], Test Accuracy: 70.00%
# Epoch [424/1000], Test Accuracy: 65.00%
# Epoch [425/1000], Test Accuracy: 60.00%
# Epoch [426/1000], Test Accuracy: 75.00%
# Epoch [427/1000], Test Accuracy: 75.00%
# Epoch [428/1000], Test Accuracy: 75.00%
# Epoch [429/1000], Test Accuracy: 70.00%
# Epoch [430/1000], Test Accuracy: 70.00%
# Epoch [431/1000], Test Accuracy: 80.00%
# Epoch [432/1000], Test Accuracy: 75.00%
# Epoch [433/1000], Test Accuracy: 65.00%
# Epoch [434/1000], Test Accuracy: 65.00%
# Epoch [435/1000], Test Accuracy: 70.00%
# Epoch [436/1000], Test Accuracy: 80.00%
# Epoch [437/1000], Test Accuracy: 75.00%
# Epoch [438/1000], Test Accuracy: 65.00%
# Epoch [439/1000], Test Accuracy: 60.00%
# Epoch [440/1000], Test Accuracy: 70.00%
# Epoch [441/1000], Test Accuracy: 75.00%
# Epoch [442/1000], Test Accuracy: 75.00%
# Epoch [443/1000], Test Accuracy: 65.00%
# Epoch [444/1000], Test Accuracy: 60.00%
# Epoch [445/1000], Test Accuracy: 70.00%
# Epoch [446/1000], Test Accuracy: 75.00%
# Epoch [447/1000], Test Accuracy: 75.00%
# Epoch [448/1000], Test Accuracy: 70.00%
# Epoch [449/1000], Test Accuracy: 60.00%
# Epoch [450/1000], Test Accuracy: 75.00%
# Epoch [451/1000], Test Accuracy: 80.00%
# Epoch [452/1000], Test Accuracy: 80.00%
# Epoch [453/1000], Test Accuracy: 65.00%
# Epoch [454/1000], Test Accuracy: 65.00%
# Epoch [455/1000], Test Accuracy: 75.00%
# Epoch [456/1000], Test Accuracy: 80.00%
# Epoch [457/1000], Test Accuracy: 70.00%
# Epoch [458/1000], Test Accuracy: 65.00%
# Epoch [459/1000], Test Accuracy: 65.00%
# Epoch [460/1000], Test Accuracy: 65.00%
# Epoch [461/1000], Test Accuracy: 75.00%
# Epoch [462/1000], Test Accuracy: 75.00%
# Epoch [463/1000], Test Accuracy: 65.00%
# Epoch [464/1000], Test Accuracy: 65.00%
# Epoch [465/1000], Test Accuracy: 70.00%
# Epoch [466/1000], Test Accuracy: 80.00%
# Epoch [467/1000], Test Accuracy: 80.00%
# Epoch [468/1000], Test Accuracy: 70.00%
# Epoch [469/1000], Test Accuracy: 70.00%
# Epoch [470/1000], Test Accuracy: 75.00%
# Epoch [471/1000], Test Accuracy: 75.00%
# Epoch [472/1000], Test Accuracy: 70.00%
# Epoch [473/1000], Test Accuracy: 70.00%
# Epoch [474/1000], Test Accuracy: 65.00%
# Epoch [475/1000], Test Accuracy: 75.00%
# Epoch [476/1000], Test Accuracy: 75.00%
# Epoch [477/1000], Test Accuracy: 70.00%
# Epoch [478/1000], Test Accuracy: 75.00%
# Epoch [479/1000], Test Accuracy: 80.00%
# Epoch [480/1000], Test Accuracy: 70.00%
# Epoch [481/1000], Test Accuracy: 65.00%
# Epoch [482/1000], Test Accuracy: 65.00%
# Epoch [483/1000], Test Accuracy: 75.00%
# Epoch [484/1000], Test Accuracy: 80.00%
# Epoch [485/1000], Test Accuracy: 80.00%
# Epoch [486/1000], Test Accuracy: 65.00%
# Epoch [487/1000], Test Accuracy: 70.00%
# Epoch [488/1000], Test Accuracy: 70.00%
# Epoch [489/1000], Test Accuracy: 80.00%
# Epoch [490/1000], Test Accuracy: 60.00%
# Epoch [491/1000], Test Accuracy: 60.00%
# Epoch [492/1000], Test Accuracy: 75.00%
# Epoch [493/1000], Test Accuracy: 80.00%
# Epoch [494/1000], Test Accuracy: 75.00%
# Epoch [495/1000], Test Accuracy: 60.00%
# Epoch [496/1000], Test Accuracy: 65.00%
# Epoch [497/1000], Test Accuracy: 80.00%
# Epoch [498/1000], Test Accuracy: 80.00%
# Epoch [499/1000], Test Accuracy: 75.00%
# Epoch [500/1000], Test Accuracy: 70.00%
# Epoch [501/1000], Test Accuracy: 70.00%
# Epoch [502/1000], Test Accuracy: 75.00%
# Epoch [503/1000], Test Accuracy: 75.00%
# Epoch [504/1000], Test Accuracy: 80.00%
# Epoch [505/1000], Test Accuracy: 65.00%
# Epoch [506/1000], Test Accuracy: 65.00%
# Epoch [507/1000], Test Accuracy: 70.00%
# Epoch [508/1000], Test Accuracy: 80.00%
# Epoch [509/1000], Test Accuracy: 80.00%
# Epoch [510/1000], Test Accuracy: 65.00%
# Epoch [511/1000], Test Accuracy: 70.00%
# Epoch [512/1000], Test Accuracy: 75.00%
# Epoch [513/1000], Test Accuracy: 80.00%
# Epoch [514/1000], Test Accuracy: 75.00%
# Epoch [515/1000], Test Accuracy: 70.00%
# Epoch [516/1000], Test Accuracy: 70.00%
# Epoch [517/1000], Test Accuracy: 70.00%
# Epoch [518/1000], Test Accuracy: 70.00%
# Epoch [519/1000], Test Accuracy: 65.00%
# Epoch [520/1000], Test Accuracy: 70.00%
# Epoch [521/1000], Test Accuracy: 80.00%
# Epoch [522/1000], Test Accuracy: 80.00%
# Epoch [523/1000], Test Accuracy: 75.00%
# Epoch [524/1000], Test Accuracy: 65.00%
# Epoch [525/1000], Test Accuracy: 75.00%
# Epoch [526/1000], Test Accuracy: 75.00%
# Epoch [527/1000], Test Accuracy: 70.00%
# Epoch [528/1000], Test Accuracy: 65.00%
# Epoch [529/1000], Test Accuracy: 80.00%
# Epoch [530/1000], Test Accuracy: 80.00%
# Epoch [531/1000], Test Accuracy: 75.00%
# Epoch [532/1000], Test Accuracy: 70.00%
# Epoch [533/1000], Test Accuracy: 75.00%
# Epoch [534/1000], Test Accuracy: 80.00%
# Epoch [535/1000], Test Accuracy: 75.00%
# Epoch [536/1000], Test Accuracy: 65.00%
# Epoch [537/1000], Test Accuracy: 65.00%
# Epoch [538/1000], Test Accuracy: 75.00%
# Epoch [539/1000], Test Accuracy: 80.00%
# Epoch [540/1000], Test Accuracy: 75.00%
# Epoch [541/1000], Test Accuracy: 70.00%
# Epoch [542/1000], Test Accuracy: 65.00%
# Epoch [543/1000], Test Accuracy: 70.00%
# Epoch [544/1000], Test Accuracy: 70.00%
# Epoch [545/1000], Test Accuracy: 75.00%
# Epoch [546/1000], Test Accuracy: 75.00%
# Epoch [547/1000], Test Accuracy: 75.00%
# Epoch [548/1000], Test Accuracy: 70.00%
# Epoch [549/1000], Test Accuracy: 65.00%
# Epoch [550/1000], Test Accuracy: 70.00%
# Epoch [551/1000], Test Accuracy: 70.00%
# Epoch [552/1000], Test Accuracy: 70.00%
# Epoch [553/1000], Test Accuracy: 75.00%
# Epoch [554/1000], Test Accuracy: 75.00%
# Epoch [555/1000], Test Accuracy: 65.00%
# Epoch [556/1000], Test Accuracy: 75.00%
# Epoch [557/1000], Test Accuracy: 75.00%
# Epoch [558/1000], Test Accuracy: 75.00%
# Epoch [559/1000], Test Accuracy: 75.00%
# Epoch [560/1000], Test Accuracy: 75.00%
# Epoch [561/1000], Test Accuracy: 75.00%
# Epoch [562/1000], Test Accuracy: 70.00%
# Epoch [563/1000], Test Accuracy: 70.00%
# Epoch [564/1000], Test Accuracy: 70.00%
# Epoch [565/1000], Test Accuracy: 80.00%
# Epoch [566/1000], Test Accuracy: 70.00%
# Epoch [567/1000], Test Accuracy: 65.00%
# Epoch [568/1000], Test Accuracy: 70.00%
# Epoch [569/1000], Test Accuracy: 80.00%
# Epoch [570/1000], Test Accuracy: 80.00%
# Epoch [571/1000], Test Accuracy: 70.00%
# Epoch [572/1000], Test Accuracy: 75.00%
# Epoch [573/1000], Test Accuracy: 70.00%
# Epoch [574/1000], Test Accuracy: 80.00%
# Epoch [575/1000], Test Accuracy: 65.00%
# Epoch [576/1000], Test Accuracy: 70.00%
# Epoch [577/1000], Test Accuracy: 75.00%
# Epoch [578/1000], Test Accuracy: 75.00%
# Epoch [579/1000], Test Accuracy: 75.00%
# Epoch [580/1000], Test Accuracy: 70.00%
# Epoch [581/1000], Test Accuracy: 75.00%
# Epoch [582/1000], Test Accuracy: 80.00%
# Epoch [583/1000], Test Accuracy: 75.00%
# Epoch [584/1000], Test Accuracy: 70.00%
# Epoch [585/1000], Test Accuracy: 70.00%
# Epoch [586/1000], Test Accuracy: 75.00%
# Epoch [587/1000], Test Accuracy: 75.00%
# Epoch [588/1000], Test Accuracy: 75.00%
# Epoch [589/1000], Test Accuracy: 70.00%
# Epoch [590/1000], Test Accuracy: 65.00%
# Epoch [591/1000], Test Accuracy: 60.00%
# Epoch [592/1000], Test Accuracy: 80.00%
# Epoch [593/1000], Test Accuracy: 80.00%
# Epoch [594/1000], Test Accuracy: 75.00%
# Epoch [595/1000], Test Accuracy: 75.00%
# Epoch [596/1000], Test Accuracy: 80.00%
# Epoch [597/1000], Test Accuracy: 75.00%
# Epoch [598/1000], Test Accuracy: 75.00%
# Epoch [599/1000], Test Accuracy: 70.00%
# Epoch [600/1000], Test Accuracy: 70.00%
# Epoch [601/1000], Test Accuracy: 80.00%
# Epoch [602/1000], Test Accuracy: 80.00%
# Epoch [603/1000], Test Accuracy: 75.00%
# Epoch [604/1000], Test Accuracy: 75.00%
# Epoch [605/1000], Test Accuracy: 75.00%
# Epoch [606/1000], Test Accuracy: 65.00%
# Epoch [607/1000], Test Accuracy: 75.00%
# Epoch [608/1000], Test Accuracy: 80.00%
# Epoch [609/1000], Test Accuracy: 75.00%
# Epoch [610/1000], Test Accuracy: 65.00%
# Epoch [611/1000], Test Accuracy: 65.00%
# Epoch [612/1000], Test Accuracy: 70.00%
# Epoch [613/1000], Test Accuracy: 75.00%
# Epoch [614/1000], Test Accuracy: 75.00%
# Epoch [615/1000], Test Accuracy: 80.00%
# Epoch [616/1000], Test Accuracy: 80.00%
# Epoch [617/1000], Test Accuracy: 65.00%
# Epoch [618/1000], Test Accuracy: 65.00%
# Epoch [619/1000], Test Accuracy: 80.00%
# Epoch [620/1000], Test Accuracy: 80.00%
# Epoch [621/1000], Test Accuracy: 75.00%
# Epoch [622/1000], Test Accuracy: 60.00%
# Epoch [623/1000], Test Accuracy: 65.00%
# Epoch [624/1000], Test Accuracy: 70.00%
# Epoch [625/1000], Test Accuracy: 80.00%
# Epoch [626/1000], Test Accuracy: 70.00%
# Epoch [627/1000], Test Accuracy: 75.00%
# Epoch [628/1000], Test Accuracy: 65.00%
# Epoch [629/1000], Test Accuracy: 75.00%
# Epoch [630/1000], Test Accuracy: 75.00%
# Epoch [631/1000], Test Accuracy: 80.00%
# Epoch [632/1000], Test Accuracy: 75.00%
# Epoch [633/1000], Test Accuracy: 70.00%
# Epoch [634/1000], Test Accuracy: 80.00%
# Epoch [635/1000], Test Accuracy: 80.00%
# Epoch [636/1000], Test Accuracy: 70.00%
# Epoch [637/1000], Test Accuracy: 70.00%
# Epoch [638/1000], Test Accuracy: 80.00%
# Epoch [639/1000], Test Accuracy: 80.00%
# Epoch [640/1000], Test Accuracy: 80.00%
# Epoch [641/1000], Test Accuracy: 65.00%
# Epoch [642/1000], Test Accuracy: 75.00%
# Epoch [643/1000], Test Accuracy: 75.00%
# Epoch [644/1000], Test Accuracy: 80.00%
# Epoch [645/1000], Test Accuracy: 65.00%
# Epoch [646/1000], Test Accuracy: 75.00%
# Epoch [647/1000], Test Accuracy: 70.00%
# Epoch [648/1000], Test Accuracy: 80.00%
# Epoch [649/1000], Test Accuracy: 70.00%
# Epoch [650/1000], Test Accuracy: 65.00%
# Epoch [651/1000], Test Accuracy: 75.00%
# Epoch [652/1000], Test Accuracy: 75.00%
# Epoch [653/1000], Test Accuracy: 80.00%
# Epoch [654/1000], Test Accuracy: 75.00%
# Epoch [655/1000], Test Accuracy: 75.00%
# Epoch [656/1000], Test Accuracy: 75.00%
# Epoch [657/1000], Test Accuracy: 70.00%
# Epoch [658/1000], Test Accuracy: 65.00%
# Epoch [659/1000], Test Accuracy: 75.00%
# Epoch [660/1000], Test Accuracy: 75.00%
# Epoch [661/1000], Test Accuracy: 80.00%
# Epoch [662/1000], Test Accuracy: 70.00%
# Epoch [663/1000], Test Accuracy: 75.00%
# Epoch [664/1000], Test Accuracy: 80.00%
# Epoch [665/1000], Test Accuracy: 80.00%
# Epoch [666/1000], Test Accuracy: 75.00%
# Epoch [667/1000], Test Accuracy: 65.00%
# Epoch [668/1000], Test Accuracy: 80.00%
# Epoch [669/1000], Test Accuracy: 80.00%
# Epoch [670/1000], Test Accuracy: 75.00%
# Epoch [671/1000], Test Accuracy: 75.00%
# Epoch [672/1000], Test Accuracy: 75.00%
# Epoch [673/1000], Test Accuracy: 80.00%
# Epoch [674/1000], Test Accuracy: 80.00%
# Epoch [675/1000], Test Accuracy: 80.00%
# Epoch [676/1000], Test Accuracy: 80.00%
# Epoch [677/1000], Test Accuracy: 80.00%
# Epoch [678/1000], Test Accuracy: 75.00%
# Epoch [679/1000], Test Accuracy: 65.00%
# Epoch [680/1000], Test Accuracy: 65.00%
# Epoch [681/1000], Test Accuracy: 80.00%
# Epoch [682/1000], Test Accuracy: 75.00%
# Epoch [683/1000], Test Accuracy: 75.00%
# Epoch [684/1000], Test Accuracy: 70.00%
# Epoch [685/1000], Test Accuracy: 80.00%
# Epoch [686/1000], Test Accuracy: 80.00%
# Epoch [687/1000], Test Accuracy: 75.00%
# Epoch [688/1000], Test Accuracy: 75.00%
# Epoch [689/1000], Test Accuracy: 75.00%
# Epoch [690/1000], Test Accuracy: 80.00%
# Epoch [691/1000], Test Accuracy: 75.00%
# Epoch [692/1000], Test Accuracy: 80.00%
# Epoch [693/1000], Test Accuracy: 80.00%
# Epoch [694/1000], Test Accuracy: 80.00%
# Epoch [695/1000], Test Accuracy: 65.00%
# Epoch [696/1000], Test Accuracy: 65.00%
# Epoch [697/1000], Test Accuracy: 75.00%
# Epoch [698/1000], Test Accuracy: 80.00%
# Epoch [699/1000], Test Accuracy: 80.00%
# Epoch [700/1000], Test Accuracy: 80.00%
# Epoch [701/1000], Test Accuracy: 80.00%
# Epoch [702/1000], Test Accuracy: 70.00%
# Epoch [703/1000], Test Accuracy: 80.00%
# Epoch [704/1000], Test Accuracy: 80.00%
# Epoch [705/1000], Test Accuracy: 80.00%
# Epoch [706/1000], Test Accuracy: 60.00%
# Epoch [707/1000], Test Accuracy: 65.00%
# Epoch [708/1000], Test Accuracy: 80.00%
# Epoch [709/1000], Test Accuracy: 80.00%
# Epoch [710/1000], Test Accuracy: 80.00%
# Epoch [711/1000], Test Accuracy: 80.00%
# Epoch [712/1000], Test Accuracy: 70.00%
# Epoch [713/1000], Test Accuracy: 65.00%
# Epoch [714/1000], Test Accuracy: 80.00%
# Epoch [715/1000], Test Accuracy: 75.00%
# Epoch [716/1000], Test Accuracy: 75.00%
# Epoch [717/1000], Test Accuracy: 80.00%
# Epoch [718/1000], Test Accuracy: 80.00%
# Epoch [719/1000], Test Accuracy: 80.00%
# Epoch [720/1000], Test Accuracy: 80.00%
# Epoch [721/1000], Test Accuracy: 80.00%
# Epoch [722/1000], Test Accuracy: 80.00%
# Epoch [723/1000], Test Accuracy: 80.00%
# Epoch [724/1000], Test Accuracy: 80.00%
# Epoch [725/1000], Test Accuracy: 80.00%
# Epoch [726/1000], Test Accuracy: 80.00%
# Epoch [727/1000], Test Accuracy: 80.00%
# Epoch [728/1000], Test Accuracy: 80.00%
# Epoch [729/1000], Test Accuracy: 80.00%
# Epoch [730/1000], Test Accuracy: 75.00%
# Epoch [731/1000], Test Accuracy: 75.00%
# Epoch [732/1000], Test Accuracy: 80.00%
# Epoch [733/1000], Test Accuracy: 80.00%
# Epoch [734/1000], Test Accuracy: 80.00%
# Epoch [735/1000], Test Accuracy: 75.00%
# Epoch [736/1000], Test Accuracy: 75.00%
# Epoch [737/1000], Test Accuracy: 80.00%
# Epoch [738/1000], Test Accuracy: 80.00%
# Epoch [739/1000], Test Accuracy: 80.00%
# Epoch [740/1000], Test Accuracy: 75.00%
# Epoch [741/1000], Test Accuracy: 75.00%
# Epoch [742/1000], Test Accuracy: 80.00%
# Epoch [743/1000], Test Accuracy: 70.00%
# Epoch [744/1000], Test Accuracy: 80.00%
# Epoch [745/1000], Test Accuracy: 80.00%
# Epoch [746/1000], Test Accuracy: 80.00%
# Epoch [747/1000], Test Accuracy: 80.00%
# Epoch [748/1000], Test Accuracy: 75.00%
# Epoch [749/1000], Test Accuracy: 65.00%
# Epoch [750/1000], Test Accuracy: 80.00%
# Epoch [751/1000], Test Accuracy: 80.00%
# Epoch [752/1000], Test Accuracy: 80.00%
# Epoch [753/1000], Test Accuracy: 75.00%
# Epoch [754/1000], Test Accuracy: 75.00%
# Epoch [755/1000], Test Accuracy: 75.00%
# Epoch [756/1000], Test Accuracy: 65.00%
# Epoch [757/1000], Test Accuracy: 65.00%
# Epoch [758/1000], Test Accuracy: 75.00%
# Epoch [759/1000], Test Accuracy: 80.00%
# Epoch [760/1000], Test Accuracy: 75.00%
# Epoch [761/1000], Test Accuracy: 65.00%
# Epoch [762/1000], Test Accuracy: 65.00%
# Epoch [763/1000], Test Accuracy: 80.00%
# Epoch [764/1000], Test Accuracy: 80.00%
# Epoch [765/1000], Test Accuracy: 80.00%
# Epoch [766/1000], Test Accuracy: 65.00%
# Epoch [767/1000], Test Accuracy: 75.00%
# Epoch [768/1000], Test Accuracy: 80.00%
# Epoch [769/1000], Test Accuracy: 65.00%
# Epoch [770/1000], Test Accuracy: 70.00%
# Epoch [771/1000], Test Accuracy: 80.00%
# Epoch [772/1000], Test Accuracy: 70.00%
# Epoch [773/1000], Test Accuracy: 80.00%
# Epoch [774/1000], Test Accuracy: 65.00%
# Epoch [775/1000], Test Accuracy: 80.00%
# Epoch [776/1000], Test Accuracy: 80.00%
# Epoch [777/1000], Test Accuracy: 80.00%
# Epoch [778/1000], Test Accuracy: 80.00%
# Epoch [779/1000], Test Accuracy: 80.00%
# Epoch [780/1000], Test Accuracy: 75.00%
# Epoch [781/1000], Test Accuracy: 75.00%
# Epoch [782/1000], Test Accuracy: 75.00%
# Epoch [783/1000], Test Accuracy: 80.00%
# Epoch [784/1000], Test Accuracy: 80.00%
# Epoch [785/1000], Test Accuracy: 80.00%
# Epoch [786/1000], Test Accuracy: 65.00%
# Epoch [787/1000], Test Accuracy: 80.00%
# Epoch [788/1000], Test Accuracy: 80.00%
# Epoch [789/1000], Test Accuracy: 80.00%
# Epoch [790/1000], Test Accuracy: 75.00%
# Epoch [791/1000], Test Accuracy: 70.00%
# Epoch [792/1000], Test Accuracy: 70.00%
# Epoch [793/1000], Test Accuracy: 80.00%
# Epoch [794/1000], Test Accuracy: 80.00%
# Epoch [795/1000], Test Accuracy: 75.00%
# Epoch [796/1000], Test Accuracy: 65.00%
# Epoch [797/1000], Test Accuracy: 75.00%
# Epoch [798/1000], Test Accuracy: 80.00%
# Epoch [799/1000], Test Accuracy: 80.00%
# Epoch [800/1000], Test Accuracy: 75.00%
# Epoch [801/1000], Test Accuracy: 80.00%
# Epoch [802/1000], Test Accuracy: 75.00%
# Epoch [803/1000], Test Accuracy: 80.00%
# Epoch [804/1000], Test Accuracy: 75.00%
# Epoch [805/1000], Test Accuracy: 75.00%
# Epoch [806/1000], Test Accuracy: 80.00%
# Epoch [807/1000], Test Accuracy: 80.00%
# Epoch [808/1000], Test Accuracy: 80.00%
# Epoch [809/1000], Test Accuracy: 75.00%
# Epoch [810/1000], Test Accuracy: 75.00%
# Epoch [811/1000], Test Accuracy: 80.00%
# Epoch [812/1000], Test Accuracy: 80.00%
# Epoch [813/1000], Test Accuracy: 80.00%
# Epoch [814/1000], Test Accuracy: 75.00%
# Epoch [815/1000], Test Accuracy: 80.00%
# Epoch [816/1000], Test Accuracy: 80.00%
# Epoch [817/1000], Test Accuracy: 80.00%
# Epoch [818/1000], Test Accuracy: 80.00%
# Epoch [819/1000], Test Accuracy: 75.00%
# Epoch [820/1000], Test Accuracy: 80.00%
# Epoch [821/1000], Test Accuracy: 80.00%
# Epoch [822/1000], Test Accuracy: 80.00%
# Epoch [823/1000], Test Accuracy: 60.00%
# Epoch [824/1000], Test Accuracy: 60.00%
# Epoch [825/1000], Test Accuracy: 80.00%
# Epoch [826/1000], Test Accuracy: 75.00%
# Epoch [827/1000], Test Accuracy: 80.00%
# Epoch [828/1000], Test Accuracy: 60.00%
# Epoch [829/1000], Test Accuracy: 60.00%
# Epoch [830/1000], Test Accuracy: 80.00%
# Epoch [831/1000], Test Accuracy: 80.00%
# Epoch [832/1000], Test Accuracy: 80.00%
# Epoch [833/1000], Test Accuracy: 80.00%
# Epoch [834/1000], Test Accuracy: 65.00%
# Epoch [835/1000], Test Accuracy: 75.00%
# Epoch [836/1000], Test Accuracy: 80.00%
# Epoch [837/1000], Test Accuracy: 80.00%
# Epoch [838/1000], Test Accuracy: 65.00%
# Epoch [839/1000], Test Accuracy: 60.00%
# Epoch [840/1000], Test Accuracy: 80.00%
# Epoch [841/1000], Test Accuracy: 75.00%
# Epoch [842/1000], Test Accuracy: 80.00%
# Epoch [843/1000], Test Accuracy: 80.00%
# Epoch [844/1000], Test Accuracy: 80.00%
# Epoch [845/1000], Test Accuracy: 80.00%
# Epoch [846/1000], Test Accuracy: 80.00%
# Epoch [847/1000], Test Accuracy: 75.00%
# Epoch [848/1000], Test Accuracy: 80.00%
# Epoch [849/1000], Test Accuracy: 80.00%
# Epoch [850/1000], Test Accuracy: 80.00%
# Epoch [851/1000], Test Accuracy: 80.00%
# Epoch [852/1000], Test Accuracy: 80.00%
# Epoch [853/1000], Test Accuracy: 80.00%
# Epoch [854/1000], Test Accuracy: 75.00%
# Epoch [855/1000], Test Accuracy: 75.00%
# Epoch [856/1000], Test Accuracy: 80.00%
# Epoch [857/1000], Test Accuracy: 75.00%
# Epoch [858/1000], Test Accuracy: 80.00%
# Epoch [859/1000], Test Accuracy: 80.00%
# Epoch [860/1000], Test Accuracy: 80.00%
# Epoch [861/1000], Test Accuracy: 75.00%
# Epoch [862/1000], Test Accuracy: 75.00%
# Epoch [863/1000], Test Accuracy: 80.00%
# Epoch [864/1000], Test Accuracy: 80.00%
# Epoch [865/1000], Test Accuracy: 80.00%
# Epoch [866/1000], Test Accuracy: 75.00%
# Epoch [867/1000], Test Accuracy: 70.00%
# Epoch [868/1000], Test Accuracy: 80.00%
# Epoch [869/1000], Test Accuracy: 80.00%
# Epoch [870/1000], Test Accuracy: 75.00%
# Epoch [871/1000], Test Accuracy: 80.00%
# Epoch [872/1000], Test Accuracy: 80.00%
# Epoch [873/1000], Test Accuracy: 75.00%
# Epoch [874/1000], Test Accuracy: 70.00%
# Epoch [875/1000], Test Accuracy: 80.00%
# Epoch [876/1000], Test Accuracy: 80.00%
# Epoch [877/1000], Test Accuracy: 70.00%
# Epoch [878/1000], Test Accuracy: 75.00%
# Epoch [879/1000], Test Accuracy: 80.00%
# Epoch [880/1000], Test Accuracy: 80.00%
# Epoch [881/1000], Test Accuracy: 75.00%
# Epoch [882/1000], Test Accuracy: 65.00%
# Epoch [883/1000], Test Accuracy: 75.00%
# Epoch [884/1000], Test Accuracy: 75.00%
# Epoch [885/1000], Test Accuracy: 80.00%
# Epoch [886/1000], Test Accuracy: 75.00%
# Epoch [887/1000], Test Accuracy: 75.00%
# Epoch [888/1000], Test Accuracy: 80.00%
# Epoch [889/1000], Test Accuracy: 80.00%
# Epoch [890/1000], Test Accuracy: 80.00%
# Epoch [891/1000], Test Accuracy: 75.00%
# Epoch [892/1000], Test Accuracy: 75.00%
# Epoch [893/1000], Test Accuracy: 80.00%
# Epoch [894/1000], Test Accuracy: 80.00%
# Epoch [895/1000], Test Accuracy: 80.00%
# Epoch [896/1000], Test Accuracy: 75.00%
# Epoch [897/1000], Test Accuracy: 70.00%
# Epoch [898/1000], Test Accuracy: 80.00%
# Epoch [899/1000], Test Accuracy: 80.00%
# Epoch [900/1000], Test Accuracy: 80.00%
# Epoch [901/1000], Test Accuracy: 70.00%
# Epoch [902/1000], Test Accuracy: 70.00%
# Epoch [903/1000], Test Accuracy: 80.00%
# Epoch [904/1000], Test Accuracy: 80.00%
# Epoch [905/1000], Test Accuracy: 80.00%
# Epoch [906/1000], Test Accuracy: 80.00%
# Epoch [907/1000], Test Accuracy: 75.00%
# Epoch [908/1000], Test Accuracy: 80.00%
# Epoch [909/1000], Test Accuracy: 75.00%
# Epoch [910/1000], Test Accuracy: 80.00%
# Epoch [911/1000], Test Accuracy: 80.00%
# Epoch [912/1000], Test Accuracy: 70.00%
# Epoch [913/1000], Test Accuracy: 60.00%
# Epoch [914/1000], Test Accuracy: 75.00%
# Epoch [915/1000], Test Accuracy: 80.00%
# Epoch [916/1000], Test Accuracy: 80.00%
# Epoch [917/1000], Test Accuracy: 75.00%
# Epoch [918/1000], Test Accuracy: 75.00%
# Epoch [919/1000], Test Accuracy: 80.00%
# Epoch [920/1000], Test Accuracy: 80.00%
# Epoch [921/1000], Test Accuracy: 80.00%
# Epoch [922/1000], Test Accuracy: 65.00%
# Epoch [923/1000], Test Accuracy: 80.00%
# Epoch [924/1000], Test Accuracy: 80.00%
# Epoch [925/1000], Test Accuracy: 80.00%
# Epoch [926/1000], Test Accuracy: 75.00%
# Epoch [927/1000], Test Accuracy: 70.00%
# Epoch [928/1000], Test Accuracy: 80.00%
# Epoch [929/1000], Test Accuracy: 75.00%
# Epoch [930/1000], Test Accuracy: 65.00%
# Epoch [931/1000], Test Accuracy: 70.00%
# Epoch [932/1000], Test Accuracy: 70.00%
# Epoch [933/1000], Test Accuracy: 80.00%
# Epoch [934/1000], Test Accuracy: 80.00%
# Epoch [935/1000], Test Accuracy: 80.00%
# Epoch [936/1000], Test Accuracy: 80.00%
# Epoch [937/1000], Test Accuracy: 80.00%
# Epoch [938/1000], Test Accuracy: 80.00%
# Epoch [939/1000], Test Accuracy: 80.00%
# Epoch [940/1000], Test Accuracy: 75.00%
# Epoch [941/1000], Test Accuracy: 65.00%
# Epoch [942/1000], Test Accuracy: 75.00%
# Epoch [943/1000], Test Accuracy: 75.00%
# Epoch [944/1000], Test Accuracy: 75.00%
# Epoch [945/1000], Test Accuracy: 75.00%
# Epoch [946/1000], Test Accuracy: 70.00%
# Epoch [947/1000], Test Accuracy: 80.00%
# Epoch [948/1000], Test Accuracy: 75.00%
# Epoch [949/1000], Test Accuracy: 80.00%
# Epoch [950/1000], Test Accuracy: 80.00%
# Epoch [951/1000], Test Accuracy: 70.00%
# Epoch [952/1000], Test Accuracy: 70.00%
# Epoch [953/1000], Test Accuracy: 75.00%
# Epoch [954/1000], Test Accuracy: 80.00%
# Epoch [955/1000], Test Accuracy: 75.00%
# Epoch [956/1000], Test Accuracy: 70.00%
# Epoch [957/1000], Test Accuracy: 65.00%
# Epoch [958/1000], Test Accuracy: 80.00%
# Epoch [959/1000], Test Accuracy: 75.00%
# Epoch [960/1000], Test Accuracy: 80.00%
# Epoch [961/1000], Test Accuracy: 70.00%
# Epoch [962/1000], Test Accuracy: 70.00%
# Epoch [963/1000], Test Accuracy: 80.00%
# Epoch [964/1000], Test Accuracy: 80.00%
# Epoch [965/1000], Test Accuracy: 80.00%
# Epoch [966/1000], Test Accuracy: 70.00%
# Epoch [967/1000], Test Accuracy: 75.00%
# Epoch [968/1000], Test Accuracy: 75.00%
# Epoch [969/1000], Test Accuracy: 80.00%
# Epoch [970/1000], Test Accuracy: 80.00%
# Epoch [971/1000], Test Accuracy: 70.00%
# Epoch [972/1000], Test Accuracy: 55.00%
# Epoch [973/1000], Test Accuracy: 75.00%
# Epoch [974/1000], Test Accuracy: 75.00%
# Epoch [975/1000], Test Accuracy: 75.00%
# Epoch [976/1000], Test Accuracy: 75.00%
# Epoch [977/1000], Test Accuracy: 65.00%
# Epoch [978/1000], Test Accuracy: 75.00%
# Epoch [979/1000], Test Accuracy: 80.00%
# Epoch [980/1000], Test Accuracy: 80.00%
# Epoch [981/1000], Test Accuracy: 65.00%
# Epoch [982/1000], Test Accuracy: 65.00%
# Epoch [983/1000], Test Accuracy: 80.00%
# Epoch [984/1000], Test Accuracy: 75.00%
# Epoch [985/1000], Test Accuracy: 80.00%
# Epoch [986/1000], Test Accuracy: 75.00%
# Epoch [987/1000], Test Accuracy: 75.00%
# Epoch [988/1000], Test Accuracy: 80.00%
# Epoch [989/1000], Test Accuracy: 75.00%
# Epoch [990/1000], Test Accuracy: 75.00%
# Epoch [991/1000], Test Accuracy: 80.00%
# Epoch [992/1000], Test Accuracy: 80.00%
# Epoch [993/1000], Test Accuracy: 80.00%
# Epoch [994/1000], Test Accuracy: 75.00%
# Epoch [995/1000], Test Accuracy: 75.00%
# Epoch [996/1000], Test Accuracy: 75.00%
# Epoch [997/1000], Test Accuracy: 80.00%
# Epoch [998/1000], Test Accuracy: 80.00%
# Epoch [999/1000], Test Accuracy: 80.00%
# Epoch [1000/1000], Test Accuracy: 75.00%
# Best Test Accuracy: 85.00%

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

class CustomImageDataset(Dataset):
    def read_data_set(self):
        all_img_files = []
        all_labels = []

        class_names = os.walk(self.data_set_path).__next__()[1]

        for index, class_name in enumerate(class_names):
            label = index
            img_dir = os.path.join(self.data_set_path, class_name)
            img_files = os.walk(img_dir).__next__()[2]

            for img_file in img_files:
                img_file = os.path.join(img_dir, img_file)
                img = Image.open(img_file)
                if img is not None:
                    all_img_files.append(img_file)
                    all_labels.append(label)

        return all_img_files, all_labels, len(all_img_files), len(class_names)

    def __init__(self, data_set_path):
        self.data_set_path = data_set_path
        self.image_files_path, self.labels, self.length, self.num_classes = self.read_data_set()

    def __getitem__(self, index):
        image = Image.open(self.image_files_path[index])
        image = image.convert("L")
        image = image.resize((28, 28))
        image = np.array(image).astype(np.float32) / 255.0
        image = torch.from_numpy(image).unsqueeze(0)
        label = torch.tensor(self.labels[index]).long()
        return image, label

    def __len__(self):
        return self.length

class AttentionCNN(nn.Module):
    def __init__(self, num_classes):
        super(AttentionCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.attention = nn.Linear(64*7*7, 64)  # 수정: 입력 크기를 64*7*7로 변경
        self.fc = nn.Linear(64, num_classes)  # 수정: 입력 크기를 64로 변경
        
    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.pool(out)
        out = self.conv2(out)
        out = self.relu(out)
        out = self.pool(out)
        
        # Attention Mechanism
        batch_size, channels, height, width = out.size()
        attention_weights = self.attention(out.view(batch_size, -1))  # 수정: 입력을 (batch_size, 64*7*7)로 변경
        attention_weights = torch.softmax(attention_weights, dim=-1)
        attention_weights = attention_weights.unsqueeze(-1).unsqueeze(-1)  # 수정: 어텐션 가중치의 크기를 (batch_size, 64, 1, 1)로 변경
        out = out * attention_weights  # 수정: 브로드캐스팅을 사용하여 어텐션 가중치 적용
        
        out = torch.sum(out, dim=[2, 3])  # 수정: 공간 차원(height, width)에 대해 합을 계산하여 (batch_size, 64)로 변경
        out = self.fc(out)
        return out

def train(model, device, train_loader, criterion, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

def test(model, device, test_loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    accuracy = 100. * correct / len(test_loader.dataset)
    return accuracy

train_data_set = CustomImageDataset(data_set_path="./train")
test_data_set = CustomImageDataset(data_set_path="./test")

batch_size = 64
train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = train_data_set.num_classes
model = AttentionCNN(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 500
best_accuracy = 0.0

for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, criterion, optimizer, epoch)
    accuracy = test(model, device, test_loader)
    print(f"Epoch [{epoch}/{num_epochs}], Test Accuracy: {accuracy:.2f}%")
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), "best_model.pth")

print(f"Best Test Accuracy: {best_accuracy:.2f}%")
# Out:
# Epoch [1/500], Test Accuracy: 25.00%
# Epoch [2/500], Test Accuracy: 25.00%
# Epoch [3/500], Test Accuracy: 25.00%
# Epoch [4/500], Test Accuracy: 25.00%
# Epoch [5/500], Test Accuracy: 25.00%
# Epoch [6/500], Test Accuracy: 20.00%
# Epoch [7/500], Test Accuracy: 25.00%
# Epoch [8/500], Test Accuracy: 35.00%
# Epoch [9/500], Test Accuracy: 25.00%
# Epoch [10/500], Test Accuracy: 25.00%
# Epoch [11/500], Test Accuracy: 25.00%
# Epoch [12/500], Test Accuracy: 30.00%
# Epoch [13/500], Test Accuracy: 30.00%
# Epoch [14/500], Test Accuracy: 20.00%
# Epoch [15/500], Test Accuracy: 25.00%
# Epoch [16/500], Test Accuracy: 40.00%
# Epoch [17/500], Test Accuracy: 35.00%
# Epoch [18/500], Test Accuracy: 25.00%
# Epoch [19/500], Test Accuracy: 45.00%
# Epoch [20/500], Test Accuracy: 40.00%
# Epoch [21/500], Test Accuracy: 30.00%
# Epoch [22/500], Test Accuracy: 40.00%
# Epoch [23/500], Test Accuracy: 40.00%
# Epoch [24/500], Test Accuracy: 40.00%
# Epoch [25/500], Test Accuracy: 25.00%
# Epoch [26/500], Test Accuracy: 45.00%
# Epoch [27/500], Test Accuracy: 50.00%
# Epoch [28/500], Test Accuracy: 45.00%
# Epoch [29/500], Test Accuracy: 60.00%
# Epoch [30/500], Test Accuracy: 60.00%
# Epoch [31/500], Test Accuracy: 55.00%
# Epoch [32/500], Test Accuracy: 55.00%
# Epoch [33/500], Test Accuracy: 50.00%
# Epoch [34/500], Test Accuracy: 75.00%
# Epoch [35/500], Test Accuracy: 65.00%
# Epoch [36/500], Test Accuracy: 80.00%
# Epoch [37/500], Test Accuracy: 70.00%
# Epoch [38/500], Test Accuracy: 75.00%
# Epoch [39/500], Test Accuracy: 70.00%
# Epoch [40/500], Test Accuracy: 80.00%
# Epoch [41/500], Test Accuracy: 75.00%
# Epoch [42/500], Test Accuracy: 70.00%
# Epoch [43/500], Test Accuracy: 80.00%
# Epoch [44/500], Test Accuracy: 65.00%
# Epoch [45/500], Test Accuracy: 70.00%
